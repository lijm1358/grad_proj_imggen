# %%
import os
import random
import pickle
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from PIL import Image
from tqdm import tqdm

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  
    
seed = 42
seed_everything(42)

# %%
def dump_pickle(data, path):
    with open(path, "wb") as file:
        pickle.dump(data, file)

def load_pickle(path):
    with open(path, "rb") as file:
        data = pickle.load(file)
    return data

def save_pt(data, path):
    with open(path, "wb") as file:
        torch.save(data, file)

# %% [markdown]
# #### 데이터 load 및 shape 확인

# %%
item_data = pd.read_csv("./data/articles.csv")
interaction_data = pd.read_csv("./data/transactions_train.csv")

# %%
print("shape of Item data : ",item_data.shape)
print("shape of interaction data : ", interaction_data.shape)
# Out:
# shape of Item data :  (105542, 25)
# shape of interaction data :  (31788324, 5)

# %% [markdown]
# #### 이미지가 없는 아이템 찾기

# %%
def img_by_id(df, article_id:int, no_list:list, echo:int=1, img_show:bool=True):
    if article_id in no_list:
        return
    if echo:
        display(df[df.article_id == article_id])

    img_id = "0"+str(article_id)
    img = Image.open("./data/images/"+img_id[0:3]+"/"+img_id+".jpg")

    if img_show:
        img.show()

def find_no_img_item(df):
    no_img = []

    for item in tqdm(df.iterrows(), total=len(df)):
        try:
            img_by_id(df, item[1][0], no_list=no_img, echo=0, img_show=False)
        except FileNotFoundError:
            no_img.append(item[0])

    return no_img

# %%
no_img_idx = find_no_img_item(item_data)
# Out:
# 100%|██████████| 105542/105542 [00:24<00:00, 4312.82it/s]

# %%
print("# of non-img item : ",len(no_img_idx))
# Out:
# # of non-img item :  442

# %%
# 이미지가 없는 아이템 삭제
no_img_item = {idx:item_data.iloc[idx].article_id for idx in no_img_idx}
n_item_data = item_data.drop(no_img_idx, axis=0).reset_index(drop=True) # 이미지 없는 아이템을 삭제한 데이터
print("shape of n_item_data : ", n_item_data.shape)
# Out:
# shape of n_item_data :  (105100, 25)

# %%
# product_type에 속하는 상품이 10개 미만인 경우 삭제 131 -> 94로 줄어듦, 아이템은 약 130개 사라짐
n_item_data = n_item_data.groupby('product_type_no').filter(lambda x: len(x) >= 10).reset_index(drop=True)
print("shape of n_item_data : ", n_item_data.shape)
# Out:
# shape of n_item_data :  (104973, 25)

# %%
# product_type 중 불필요한 것 삭제 -> 84로 줄어듧, 아이템 400개 정도 사라짐
rm_list = ["Umbrella", "Bracelet", "Giftbox", "Waterbottle", 
           "Nipple covers", 'Chem. cosmetics', "Fine cosmetics", "Soft Toys",
           "Bra extender", "Cushion", "Side table", "Dog Wear", "Keychain",
           "Sewing kit", "Towel", "Mobile case", "Zipper head",
           "Wireless earphone case", "Stain remover spray",
           "Clothing mist", "Hair ties"]
n_item_data = n_item_data[~n_item_data['product_type_name'].isin(rm_list)].reset_index(drop=True)
print("shape of n_item_data : ", n_item_data.shape)
print("# of product_type : ", n_item_data.product_type_name.nunique())
# Out:
# shape of n_item_data :  (104572, 25)
# # of product_type :  84

# %%
# interacion data에서 앞선 과정에서 삭제된 데이터 제거
n_interaction_data = interaction_data[interaction_data['article_id'].isin(n_item_data['article_id'])].reset_index(drop=True)
print("shape of interaction data : ", interaction_data.shape)
print("shape of n_interaction_data : ", n_interaction_data.shape)
# Out:
# shape of interaction data :  (31788324, 5)
# shape of n_interaction_data :  (31550289, 5)

# %%
n_item_data = n_item_data[["article_id","product_type_no"]]

# %% [markdown]
# ### 작은 데이터 생성 (기존 데이터의 20%)

# %%
from sklearn.model_selection import train_test_split

small_interaction_data, _ = train_test_split(n_interaction_data, train_size=0.2, random_state=seed)

# %%
small_interaction_data
# Out:
#                t_dat                                        customer_id
# 21533031  2020-01-26  bc9df9b087d9f54aba50fe2a0ab838cb0a994ee67ac72c...  \
# 28284508  2020-07-02  95de2d7aef6bd87b885f49144f948c1d5efbaa1106e118...
# 20236749  2019-12-20  adad94ea244db54bd23c873a1d63776d5f554c1ef43633...
# 1509783   2018-10-22  c57de756989c61f9aec47c3a4a832bbc25dff314e4e2c1...
# 23521929  2020-03-25  14a687723e8ca90ce78f95049eeea9a8ce8ba8c521954a...
# ...              ...                                                ...
# 21081788  2020-01-13  568ff20446d7e630ec7488a99f29eab971749a04dc161e...
# 26858567  2020-06-10  8df8a7008288a8354e7f2eb261d83b8f812bc5b6293a4a...
# 23327850  2020-03-18  39b7ca4eb886a72f80a34e5bea0fff9bb18a49734ddb5e...
# 16094478  2019-09-04  2435ac495a1979f4ff35ffa1851dd9d8de597c44915824...
# 23200604  2020-03-13  593cc268d63a0898879c9f3cd39216bd0e0ff8ef15628f...
#
#           article_id     price  sales_channel_id
# 21533031   810838009  0.042356                 2
# 28284508   759479001  0.006763                 2
# 20236749   564311019  0.025407                 1
# 1509783    675443003  0.011525                 1
# 23521929   821397001  0.025407                 2
# ...              ...       ...               ...
# 21081788   781806005  0.015237                 2
# 26858567   856310003  0.025407                 2
# 23327850   858453001  0.041508                 2
# 16094478   708311020  0.044051                 1
# 23200604   728156006  0.050831                 1
#
# [6310057 rows x 5 columns]

# %%
# 이력이 7초과인 유저만 남김
small_interaction_data = small_interaction_data.groupby('customer_id').filter(lambda x: len(x) > 7).reset_index(drop=True)
print("shape of n_interaction_data : ", small_interaction_data.shape)
# Out:
# shape of n_interaction_data :  (4209754, 5)

# %%
user2idx = {v:k for k,v in enumerate(small_interaction_data['customer_id'].unique())}
item2idx = {v:k for k,v in enumerate(n_item_data['article_id'].unique())}

print("# of user", len(user2idx))
print("# of item", len(item2idx))
# Out:
# # of user 248113
# # of item 104572

# %%
# train/test split
test_data = small_interaction_data.groupby("customer_id").nth(-1)
train_data = small_interaction_data[~small_interaction_data.index.isin(test_data.index)]
test_data = test_data.reset_index(drop=True).drop(["t_dat", "price","sales_channel_id"], axis=1)
train_data = train_data.reset_index(drop=True).drop(["t_dat", "price","sales_channel_id"], axis=1)

print("shape of test_data : ", test_data.shape)
print("shape of train_data : ", train_data.shape)
# Out:
# shape of test_data :  (248113, 2)
# shape of train_data :  (3961641, 2)

# %%
train_data["customer_id"] = train_data["customer_id"].map(user2idx)
test_data["customer_id"] = test_data["customer_id"].map(user2idx)
train_data["article_id"] = train_data["article_id"].map(item2idx)
test_data["article_id"] = test_data["article_id"].map(item2idx)
n_item_data["article_id"] = n_item_data["article_id"].map(item2idx)

# %%
train_data.head()
# Out:
#    customer_id  article_id
# 0            0       69390
# 1            1       98120
# 2            2       42313
# 3            3       45500
# 4            4       85871

# %%
test_data[test_data.customer_id==0]
# Out:
#        customer_id  article_id
# 51671            0       44272

# %%
n_item_data.head()
# Out:
#    article_id  product_type_no
# 0           0              253
# 1           1              253
# 2           2              253
# 3           3              306
# 4           4              306

# %%
# product_type마다 속하는 item 목록 생성 {product_type_no : [items]}
items_by_prod_type = dict(list(n_item_data.groupby("product_type_no")))
for k in items_by_prod_type.keys():
    items_by_prod_type[k] = items_by_prod_type[k].article_id.reset_index(drop=True)

dump_pickle(items_by_prod_type, "items_by_prod_type.pkl")

# %%
# user의 pos item 목록 생성 {user_id : [items]}
pos_items_each_user = dict(list(train_data.groupby("customer_id")))
for k in pos_items_each_user.keys():
    pos_items_each_user[k] = pos_items_each_user[k].article_id.reset_index(drop=True)

dump_pickle(pos_items_each_user, "pos_items_each_user_small.pkl")

# %% [markdown]
# ### DATASET 생성

# %%
class HMTrainDataset(Dataset):
    def __init__(self, df, item_df, items_by_prod_type, pos_items_each_user) -> None:
        super().__init__()
        self.df = df
        self.item_df = item_df
        self.items_by_prod_type = items_by_prod_type
        self.pos_items_each_user = pos_items_each_user
        self.df['neg'] = np.zeros(len(self.df), dtype=int)
        self._make_triples_data()
    
    def __getitem__(self, index):
        user = self.df.customer_id[index]
        pos = self.df.article_id[index]
        neg = self.df.neg[index]
        return user, pos, neg
            
    def _neg_sampling(self, pos_list, prod_type_no):
        # 같은 prod_type_no 내에서 neg sampling
        neg = random.choice(self.items_by_prod_type[prod_type_no]) 
        while neg in pos_list:
            neg = random.choice(self.items_by_prod_type[prod_type_no])
        return neg

    def _make_triples_data(self):
        for user_id, rows in tqdm(self.df.groupby("customer_id")):
            # pos_list = {k:1 for k in pos_items_each_user[user_id]}
            pos_list = self.pos_items_each_user[user_id]
            for idx, row in rows.iterrows():
                item_id = row.article_id
                prod_type_no = self.item_df[self.item_df["article_id"] == item_id].product_type_no.item()
                self.df.at[idx, 'neg'] = self._neg_sampling(pos_list, prod_type_no)
    
    def __len__(self):
        return len(self.df)

# %%
class HMTestDataset(Dataset):
    def __init__(self, df) -> None:
        super().__init__()
        self.df = df
        
    def __getitem__(self, index):
        user = self.df.customer_id[index]
        pos = self.df.article_id[index]
        return user, pos

    def __len__(self):
        return len(self.df)

# %%
train_dataset = HMTrainDataset(train_data, n_item_data, items_by_prod_type, pos_items_each_user)
save_pt(train_dataset, "./dataset/train_dataset_v1.pt")
# Out:
# 100%|██████████| 248113/248113 [09:15<00:00, 446.70it/s]

# %%
test_dataset = HMTestDataset(test_data)
save_pt(test_dataset, "./dataset/test_dataset_v1.pt")

# %%
import timeit

def function_1(pos_list, n_item):
    neg = np.random.randint(0, n_item, 1) 
    while neg in pos_list:
        neg = np.random.randint(0, n_item, 1) 
    return neg

def function_2(pos_list, n_item):
    neg = random.sample(range(0,n_item), 1) 
    while neg in pos_list:
        neg = random.sample(range(0,n_item), 1) 
    return neg

def function_3(pos_list, n_item):
    neg = random.choice(range(0,n_item)) 
    while neg in pos_list:
        neg = random.choice(range(0,n_item)) 
    return neg

n_item = len(item2idx)
pos = random.sample(range(1,n_item), 40)
n = 315500

time_1 = timeit.timeit('function_1(pos, n_item)', globals=globals(), number=n)
time_2 = timeit.timeit('function_2(pos, n_item)', globals=globals(), number=n)
time_3 = timeit.timeit('function_2(pos, n_item)', globals=globals(), number=n)

print(f'np.random.randint 실행 시간: {time_1} 초')
print(f'random.sample 실행 시간: {time_2} 초')
print(f'random.choice 실행 시간: {time_3} 초')

# %%
def function_1(pos_list, n_item):
    neg = random.choice(range(0,n_item)) 
    while neg in pos_list:
        neg = random.choice(range(0,n_item)) 
    return neg

def function_2(pos_list, n_item):
    pos_list = {k:1 for k in pos_list}
    neg = random.choice(range(0,n_item)) 
    while neg in pos_list:
        neg = random.choice(range(0,n_item)) 
    return neg

n_item = len(item2idx)
pos = random.sample(range(1,n_item), 40)
n = 315500

time_1 = timeit.timeit('function_1(pos, n_item)', globals=globals(), number=n)
time_2 = timeit.timeit('function_2(pos, n_item)', globals=globals(), number=n)

print(f'list 실행 시간: {time_1} 초')
print(f'dict 실행 시간: {time_2} 초')

# %%
import numpy as np
import timeit
import random
import torch

def function_1(pos_list, all_item):
    candicate_items = torch.tensor(list(all_item - set(pos_list)))

def function_2(pos_list, all_item):
    candicate_items = torch.tensor(np.setdiff1d(all_item, pos_list))
   
def function_3():
    items_set = set(range(1,104573))
    
def function_4():
    items_np = np.arange(104573, dtype=np.int32)
    

items_set = set(range(1,104573))
items_np = np.arange(104573, dtype=np.int32)
pos = random.sample(range(1,104573), 40)
n1 = 74570
n2 = 4000

time_1 = timeit.timeit('function_1(pos, items_set)', globals=globals(), number=n1)
print(f'list(set) 실행 시간: {time_1} 초')

time_2 = timeit.timeit('function_2(pos, items_np)', globals=globals(), number=n1)
print(f'np.setdiff1d 실행 시간: {time_2} 초')

time_3 = timeit.timeit('function_3()', globals=globals(), number=n2)
print(f'set 실행 시간: {time_3} 초')

time_4 = timeit.timeit('function_4()', globals=globals(), number=n2)
print(f'np.arange 실행 시간: {time_4} 초')
# Out:
# list(set) 실행 시간: 508.1635248339999 초
# np.setdiff1d 실행 시간: 69.18620454200027 초
# set 실행 시간: 5.8264562089998435 초
# np.arange 실행 시간: 0.028278708000470942 초

# %%
import numpy as np
import timeit
import random
import torch

def function_1(pos_list, all_item):
    candicate_items = torch.tensor(np.random.choice(np.setdiff1d(all_item, pos_list), 100))


def function_2(pos_list, all_item):
    candicate_items = torch.tensor(random.sample(list(np.setdiff1d(all_item, pos_list)), 100))
    

# items_set = set(range(1,104573))
items_np = np.arange(104573, dtype=np.int32)
pos = random.sample(range(1,104573), 40)
n1 = 24570
n2 = 4000

time_1 = timeit.timeit('function_1(pos, items_np)', globals=globals(), number=n1)
print(f'np.random.choice 실행 시간: {time_1} 초')

time_2 = timeit.timeit('function_2(pos, items_np)', globals=globals(), number=n1)
print(f'random.sample + list 실행 시간: {time_2} 초')
# Out:
# np.random.choice 실행 시간: 21.930991625000388 초
# (random.sample + list 실행 시간: 69.53751850000117 초

# %% [markdown]
# #### 아이템 이미지 임베딩 생성

# %%
from fashion_clip.fashion_clip import FashionCLIP
fclip = FashionCLIP('fashion-clip')

images = ["./data/images/" + "0" + str(k)[0:2] + "/" + "0"+str(k) + ".jpg" for k in n_item_data["article_id"].tolist()]
image_embeddings = fclip.encode_images(images, batch_size=64)

# %%
# 이미지 임베딩을 pkl 파일로 저장하고 싶은 경우 실행
dump_pickle(image_embeddings, "./data/img_emb.pkl")

# %%
res = load_pickle("/home/gcpu293/Grad_proj/VBPR/data/res/20151336_0.pkl")

# %%
res
# Out:
# {31197: tensor([], device='cuda:0', dtype=torch.int64),
#  54995: tensor([], device='cuda:0', dtype=torch.int64),
#  32843: tensor([], device='cuda:0', dtype=torch.int64),
#  57843: tensor([], device='cuda:0', dtype=torch.int64),
#  70896: tensor([], device='cuda:0', dtype=torch.int64),
#  73756: tensor([], device='cuda:0', dtype=torch.int64),
#  96333: tensor([], device='cuda:0', dtype=torch.int64),
#  49253: tensor([], device='cuda:0', dtype=torch.int64),
#  29124: tensor([], device='cuda:0', dtype=torch.int64),
#  94117: tensor([], device='cuda:0', dtype=torch.int64),
#  52309: tensor([], device='cuda:0', dtype=torch.int64),
#  100477: tensor([], device='cuda:0', dtype=torch.int64),
#  47577: tensor([], device='cuda:0', dtype=torch.int64),
#  61847: tensor([], device='cuda:0', dtype=torch.int64),
#  82547: tensor([], device='cuda:0', dtype=torch.int64),
#  54232: tensor([], device='cuda:0', dtype=torch.int64),
#  57648: tensor([], device='cuda:0', dtype=torch.int64),
#  96764: tensor([], device='cuda:0', dtype=torch.int64),
#  92161: tensor([], device='cuda:0', dtype=torch.int64),
#  56987: tensor([], device='cuda:0', dtype=torch.int64),
#  3627: tensor([], device='cuda:0', dtype=torch.int64),
#  28048: tensor([], device='cuda:0', dtype=torch.int64),
#  14864: tensor([], device='cuda:0', dtype=torch.int64),
#  69488: tensor([], device='cuda:0', dtype=torch.int64),
#  5947: tensor([], device='cuda:0', dtype=torch.int64),
#  2185: tensor([], device='cuda:0', dtype=torch.int64),
#  19765: tensor([], device='cuda:0', dtype=torch.int64),
#  40437: tensor([], device='cuda:0', dtype=torch.int64),
#  88016: tensor([], device='cuda:0', dtype=torch.int64),
#  5357: tensor([], device='cuda:0', dtype=torch.int64),
#  51494: tensor([], device='cuda:0', dtype=torch.int64),
#  3147: tensor([], device='cuda:0', dtype=torch.int64),
#  13482: tensor([], device='cuda:0', dtype=torch.int64),
#  31208: tensor([], device='cuda:0', dtype=torch.int64),
#  92774: tensor([], device='cuda:0', dtype=torch.int64),
#  33715: tensor([], device='cuda:0', dtype=torch.int64),
#  82546: tensor([], device='cuda:0', dtype=torch.int64),
#  54113: tensor([], device='cuda:0', dtype=torch.int64),
#  92654: tensor([], device='cuda:0', dtype=torch.int64),
#  41213: tensor([], device='cuda:0', dtype=torch.int64),
#  55141: tensor([], device='cuda:0', dtype=torch.int64),
#  22053: tensor([], device='cuda:0', dtype=torch.int64),
#  51085: tensor([], device='cuda:0', dtype=torch.int64),
#  6525: tensor([], device='cuda:0', dtype=torch.int64),
#  69589: tensor([], device='cuda:0', dtype=torch.int64),
#  74337: tensor([], device='cuda:0', dtype=torch.int64),
#  29931: tensor([], device='cuda:0', dtype=torch.int64),
#  79129: tensor([], device='cuda:0', dtype=torch.int64),
#  85021: tensor([], device='cuda:0', dtype=torch.int64),
#  74223: tensor([], device='cuda:0', dtype=torch.int64),
#  37052: tensor([], device='cuda:0', dtype=torch.int64),
#  29848: tensor([], device='cuda:0', dtype=torch.int64),
#  72499: tensor([], device='cuda:0', dtype=torch.int64),
#  62803: tensor([], device='cuda:0', dtype=torch.int64),
#  1669: tensor([], device='cuda:0', dtype=torch.int64),
#  108: tensor([], device='cuda:0', dtype=torch.int64),
#  22052: tensor([], device='cuda:0', dtype=torch.int64),
#  86956: tensor([], device='cuda:0', dtype=torch.int64),
#  93206: tensor([], device='cuda:0', dtype=torch.int64),
#  10619: tensor([], device='cuda:0', dtype=torch.int64),
#  97339: tensor([], device='cuda:0', dtype=torch.int64),
#  84586: tensor([], device='cuda:0', dtype=torch.int64),
#  76191: tensor([], device='cuda:0', dtype=torch.int64),
#  73260: tensor([], device='cuda:0', dtype=torch.int64),
#  64158: tensor([], device='cuda:0', dtype=torch.int64),
#  39786: tensor([], device='cuda:0', dtype=torch.int64),
#  73757: tensor([], device='cuda:0', dtype=torch.int64),
#  98032: tensor([], device='cuda:0', dtype=torch.int64),
#  54822: tensor([], device='cuda:0', dtype=torch.int64),
#  27196: tensor([], device='cuda:0', dtype=torch.int64),
#  63632: tensor([], device='cuda:0', dtype=torch.int64),
#  60843: tensor([], device='cuda:0', dtype=torch.int64),
#  3769: tensor([], device='cuda:0', dtype=torch.int64),
#  1638: tensor([], device='cuda:0', dtype=torch.int64),
#  2286: tensor([], device='cuda:0', dtype=torch.int64),
#  70047: tensor([], device='cuda:0', dtype=torch.int64),
#  3200: tensor([], device='cuda:0', dtype=torch.int64),
#  26032: tensor([], device='cuda:0', dtype=torch.int64),
#  49285: tensor([], device='cuda:0', dtype=torch.int64),
#  80957: tensor([], device='cuda:0', dtype=torch.int64),
#  94558: tensor([], device='cuda:0', dtype=torch.int64),
#  74: tensor([], device='cuda:0', dtype=torch.int64),
#  55348: tensor([], device='cuda:0', dtype=torch.int64),
#  12506: tensor([ 99463,  92614,  57429,  85210,  98871,  89187,  86086,  10621,  34962,
#           89447, 103589,  30263,  12506,   5289,  35303,  77406,  87851,  15279,
#           78365,  37093], device='cuda:0'),
#  60678: tensor([], device='cuda:0', dtype=torch.int64),
#  67568: tensor([], device='cuda:0', dtype=torch.int64),
#  76636: tensor([], device='cuda:0', dtype=torch.int64),
#  74340: tensor([], device='cuda:0', dtype=torch.int64),
#  12692: tensor([], device='cuda:0', dtype=torch.int64),
#  60754: tensor([], device='cuda:0', dtype=torch.int64),
#  51513: tensor([], device='cuda:0', dtype=torch.int64),
#  92530: tensor([], device='cuda:0', dtype=torch.int64),
#  92155: tensor([], device='cuda:0', dtype=torch.int64),
#  39679: tensor([], device='cuda:0', dtype=torch.int64),
#  41742: tensor([], device='cuda:0', dtype=torch.int64),
#  50048: tensor([], device='cuda:0', dtype=torch.int64),
#  46673: tensor([], device='cuda:0', dtype=torch.int64),
#  13026: tensor([], device='cuda:0', dtype=torch.int64),
#  44636: tensor([], device='cuda:0', dtype=torch.int64),
#  43100: tensor([], device='cuda:0', dtype=torch.int64),
#  55103: tensor([], device='cuda:0', dtype=torch.int64),
#  30167: tensor([], device='cuda:0', dtype=torch.int64),
#  37297: tensor([], device='cuda:0', dtype=torch.int64),
#  93815: tensor([], device='cuda:0', dtype=torch.int64),
#  64157: tensor([], device='cuda:0', dtype=torch.int64),
#  74367: tensor([], device='cuda:0', dtype=torch.int64),
#  53655: tensor([], device='cuda:0', dtype=torch.int64),
#  79282: tensor([], device='cuda:0', dtype=torch.int64),
#  93422: tensor([], device='cuda:0', dtype=torch.int64),
#  88015: tensor([], device='cuda:0', dtype=torch.int64),
#  65835: tensor([], device='cuda:0', dtype=torch.int64),
#  83804: tensor([], device='cuda:0', dtype=torch.int64),
#  7373: tensor([], device='cuda:0', dtype=torch.int64),
#  96601: tensor([], device='cuda:0', dtype=torch.int64),
#  170: tensor([], device='cuda:0', dtype=torch.int64),
#  65758: tensor([], device='cuda:0', dtype=torch.int64),
#  79298: tensor([], device='cuda:0', dtype=torch.int64),
#  94513: tensor([], device='cuda:0', dtype=torch.int64),
#  72326: tensor([], device='cuda:0', dtype=torch.int64),
#  491: tensor([], device='cuda:0', dtype=torch.int64),
#  56989: tensor([], device='cuda:0', dtype=torch.int64),
#  64737: tensor([], device='cuda:0', dtype=torch.int64),
#  95514: tensor([], device='cuda:0', dtype=torch.int64),
#  8906: tensor([], device='cuda:0', dtype=torch.int64),
#  88093: tensor([], device='cuda:0', dtype=torch.int64),
#  66751: tensor([], device='cuda:0', dtype=torch.int64),
#  47074: tensor([], device='cuda:0', dtype=torch.int64),
#  37870: tensor([], device='cuda:0', dtype=torch.int64),
#  9747: tensor([], device='cuda:0', dtype=torch.int64),
#  19673: tensor([], device='cuda:0', dtype=torch.int64),
#  54187: tensor([], device='cuda:0', dtype=torch.int64),
#  43913: tensor([], device='cuda:0', dtype=torch.int64),
#  591: tensor([], device='cuda:0', dtype=torch.int64),
#  52279: tensor([], device='cuda:0', dtype=torch.int64),
#  45324: tensor([], device='cuda:0', dtype=torch.int64),
#  72417: tensor([], device='cuda:0', dtype=torch.int64),
#  93822: tensor([], device='cuda:0', dtype=torch.int64),
#  56270: tensor([], device='cuda:0', dtype=torch.int64),
#  80102: tensor([], device='cuda:0', dtype=torch.int64),
#  61878: tensor([], device='cuda:0', dtype=torch.int64),
#  73194: tensor([], device='cuda:0', dtype=torch.int64),
#  68854: tensor([], device='cuda:0', dtype=torch.int64),
#  19169: tensor([], device='cuda:0', dtype=torch.int64),
#  98290: tensor([], device='cuda:0', dtype=torch.int64),
#  61958: tensor([], device='cuda:0', dtype=torch.int64),
#  29182: tensor([], device='cuda:0', dtype=torch.int64),
#  66826: tensor([], device='cuda:0', dtype=torch.int64),
#  13458: tensor([], device='cuda:0', dtype=torch.int64),
#  14515: tensor([], device='cuda:0', dtype=torch.int64),
#  36994: tensor([], device='cuda:0', dtype=torch.int64),
#  74561: tensor([], device='cuda:0', dtype=torch.int64),
#  87274: tensor([], device='cuda:0', dtype=torch.int64),
#  39285: tensor([], device='cuda:0', dtype=torch.int64),
#  49981: tensor([], device='cuda:0', dtype=torch.int64),
#  65512: tensor([], device='cuda:0', dtype=torch.int64),
#  60497: tensor([], device='cuda:0', dtype=torch.int64),
#  49460: tensor([], device='cuda:0', dtype=torch.int64),
#  954: tensor([], device='cuda:0', dtype=torch.int64),
#  63288: tensor([], device='cuda:0', dtype=torch.int64),
#  51044: tensor([], device='cuda:0', dtype=torch.int64),
#  73261: tensor([], device='cuda:0', dtype=torch.int64),
#  90538: tensor([], device='cuda:0', dtype=torch.int64),
#  32415: tensor([], device='cuda:0', dtype=torch.int64),
#  8594: tensor([], device='cuda:0', dtype=torch.int64),
#  76568: tensor([], device='cuda:0', dtype=torch.int64),
#  16148: tensor([], device='cuda:0', dtype=torch.int64),
#  40005: tensor([], device='cuda:0', dtype=torch.int64),
#  15710: tensor([], device='cuda:0', dtype=torch.int64),
#  80459: tensor([], device='cuda:0', dtype=torch.int64),
#  26485: tensor([], device='cuda:0', dtype=torch.int64),
#  1677: tensor([], device='cuda:0', dtype=torch.int64),
#  50209: tensor([], device='cuda:0', dtype=torch.int64),
#  88452: tensor([], device='cuda:0', dtype=torch.int64),
#  516: tensor([], device='cuda:0', dtype=torch.int64),
#  74946: tensor([], device='cuda:0', dtype=torch.int64),
#  32226: tensor([], device='cuda:0', dtype=torch.int64),
#  20567: tensor([], device='cuda:0', dtype=torch.int64),
#  72814: tensor([], device='cuda:0', dtype=torch.int64),
#  75851: tensor([], device='cuda:0', dtype=torch.int64),
#  15028: tensor([], device='cuda:0', dtype=torch.int64),
#  29733: tensor([], device='cuda:0', dtype=torch.int64),
#  57719: tensor([], device='cuda:0', dtype=torch.int64),
#  66752: tensor([], device='cuda:0', dtype=torch.int64),
#  73854: tensor([], device='cuda:0', dtype=torch.int64),
#  67440: tensor([], device='cuda:0', dtype=torch.int64),
#  61799: tensor([], device='cuda:0', dtype=torch.int64),
#  57717: tensor([], device='cuda:0', dtype=torch.int64),
#  92764: tensor([], device='cuda:0', dtype=torch.int64),
#  35534: tensor([], device='cuda:0', dtype=torch.int64),
#  20228: tensor([], device='cuda:0', dtype=torch.int64),
#  43564: tensor([], device='cuda:0', dtype=torch.int64),
#  793: tensor([], device='cuda:0', dtype=torch.int64),
#  66560: tensor([], device='cuda:0', dtype=torch.int64),
#  48155: tensor([], device='cuda:0', dtype=torch.int64),
#  13441: tensor([], device='cuda:0', dtype=torch.int64),
#  71933: tensor([], device='cuda:0', dtype=torch.int64),
#  34219: tensor([], device='cuda:0', dtype=torch.int64),
#  2667: tensor([], device='cuda:0', dtype=torch.int64),
#  58747: tensor([], device='cuda:0', dtype=torch.int64),
#  3691: tensor([], device='cuda:0', dtype=torch.int64),
#  16086: tensor([], device='cuda:0', dtype=torch.int64),
#  55902: tensor([], device='cuda:0', dtype=torch.int64),
#  42819: tensor([], device='cuda:0', dtype=torch.int64),
#  7330: tensor([], device='cuda:0', dtype=torch.int64),
#  99436: tensor([], device='cuda:0', dtype=torch.int64),
#  83994: tensor([], device='cuda:0', dtype=torch.int64),
#  36199: tensor([], device='cuda:0', dtype=torch.int64),
#  48192: tensor([], device='cuda:0', dtype=torch.int64),
#  41961: tensor([], device='cuda:0', dtype=torch.int64),
#  20793: tensor([], device='cuda:0', dtype=torch.int64),
#  5076: tensor([], device='cuda:0', dtype=torch.int64),
#  86925: tensor([], device='cuda:0', dtype=torch.int64),
#  93988: tensor([], device='cuda:0', dtype=torch.int64),
#  12548: tensor([], device='cuda:0', dtype=torch.int64),
#  29180: tensor([], device='cuda:0', dtype=torch.int64),
#  130: tensor([], device='cuda:0', dtype=torch.int64),
#  44607: tensor([], device='cuda:0', dtype=torch.int64),
#  71028: tensor([], device='cuda:0', dtype=torch.int64),
#  49246: tensor([], device='cuda:0', dtype=torch.int64),
#  61461: tensor([], device='cuda:0', dtype=torch.int64),
#  71406: tensor([], device='cuda:0', dtype=torch.int64),
#  16937: tensor([], device='cuda:0', dtype=torch.int64),
#  14969: tensor([], device='cuda:0', dtype=torch.int64),
#  60042: tensor([], device='cuda:0', dtype=torch.int64),
#  75222: tensor([ 67179,  94902,  63759,  79086,  51846,  97696,  98809,  37965,  81978,
#           89396,  83330,  76797,  89205,  23676,  28967, 103454,  67143,  89758,
#           85370,  12018], device='cuda:0'),
#  86332: tensor([], device='cuda:0', dtype=torch.int64),
#  71490: tensor([], device='cuda:0', dtype=torch.int64),
#  53246: tensor([], device='cuda:0', dtype=torch.int64),
#  76780: tensor([], device='cuda:0', dtype=torch.int64),
#  3492: tensor([], device='cuda:0', dtype=torch.int64),
#  64318: tensor([], device='cuda:0', dtype=torch.int64),
#  55438: tensor([], device='cuda:0', dtype=torch.int64),
#  73285: tensor([], device='cuda:0', dtype=torch.int64),
#  103938: tensor([], device='cuda:0', dtype=torch.int64),
#  364: tensor([], device='cuda:0', dtype=torch.int64),
#  93880: tensor([], device='cuda:0', dtype=torch.int64),
#  51032: tensor([], device='cuda:0', dtype=torch.int64),
#  46967: tensor([], device='cuda:0', dtype=torch.int64),
#  44187: tensor([], device='cuda:0', dtype=torch.int64),
#  46670: tensor([], device='cuda:0', dtype=torch.int64),
#  64000: tensor([], device='cuda:0', dtype=torch.int64),
#  68240: tensor([], device='cuda:0', dtype=torch.int64),
#  100938: tensor([], device='cuda:0', dtype=torch.int64),
#  65203: tensor([], device='cuda:0', dtype=torch.int64),
#  69342: tensor([], device='cuda:0', dtype=torch.int64),
#  56755: tensor([], device='cuda:0', dtype=torch.int64),
#  72336: tensor([], device='cuda:0', dtype=torch.int64),
#  56042: tensor([], device='cuda:0', dtype=torch.int64),
#  31522: tensor([], device='cuda:0', dtype=torch.int64),
#  84998: tensor([], device='cuda:0', dtype=torch.int64),
#  99964: tensor([], device='cuda:0', dtype=torch.int64),
#  7615: tensor([], device='cuda:0', dtype=torch.int64),
#  82109: tensor([], device='cuda:0', dtype=torch.int64),
#  46468: tensor([], device='cuda:0', dtype=torch.int64),
#  73958: tensor([], device='cuda:0', dtype=torch.int64),
#  46373: tensor([], device='cuda:0', dtype=torch.int64),
#  94112: tensor([], device='cuda:0', dtype=torch.int64),
#  64287: tensor([], device='cuda:0', dtype=torch.int64),
#  86307: tensor([], device='cuda:0', dtype=torch.int64),
#  83723: tensor([], device='cuda:0', dtype=torch.int64),
#  69725: tensor([], device='cuda:0', dtype=torch.int64),
#  44732: tensor([], device='cuda:0', dtype=torch.int64),
#  78171: tensor([], device='cuda:0', dtype=torch.int64),
#  84903: tensor([], device='cuda:0', dtype=torch.int64),
#  2207: tensor([], device='cuda:0', dtype=torch.int64),
#  50964: tensor([], device='cuda:0', dtype=torch.int64),
#  52748: tensor([], device='cuda:0', dtype=torch.int64),
#  18271: tensor([], device='cuda:0', dtype=torch.int64),
#  84192: tensor([], device='cuda:0', dtype=torch.int64),
#  76927: tensor([], device='cuda:0', dtype=torch.int64),
#  50627: tensor([], device='cuda:0', dtype=torch.int64),
#  36222: tensor([], device='cuda:0', dtype=torch.int64),
#  75578: tensor([], device='cuda:0', dtype=torch.int64),
#  97174: tensor([], device='cuda:0', dtype=torch.int64),
#  91026: tensor([], device='cuda:0', dtype=torch.int64),
#  56422: tensor([], device='cuda:0', dtype=torch.int64),
#  14110: tensor([], device='cuda:0', dtype=torch.int64),
#  87437: tensor([], device='cuda:0', dtype=torch.int64),
#  76457: tensor([], device='cuda:0', dtype=torch.int64),
#  57105: tensor([], device='cuda:0', dtype=torch.int64),
#  66808: tensor([], device='cuda:0', dtype=torch.int64),
#  613: tensor([], device='cuda:0', dtype=torch.int64),
#  6008: tensor([], device='cuda:0', dtype=torch.int64),
#  87714: tensor([], device='cuda:0', dtype=torch.int64),
#  90722: tensor([], device='cuda:0', dtype=torch.int64),
#  72810: tensor([], device='cuda:0', dtype=torch.int64),
#  41968: tensor([], device='cuda:0', dtype=torch.int64),
#  14013: tensor([], device='cuda:0', dtype=torch.int64),
#  45725: tensor([], device='cuda:0', dtype=torch.int64),
#  30972: tensor([], device='cuda:0', dtype=torch.int64),
#  58896: tensor([], device='cuda:0', dtype=torch.int64),
#  61802: tensor([], device='cuda:0', dtype=torch.int64),
#  78206: tensor([], device='cuda:0', dtype=torch.int64),
#  47477: tensor([], device='cuda:0', dtype=torch.int64),
#  34324: tensor([], device='cuda:0', dtype=torch.int64),
#  43469: tensor([], device='cuda:0', dtype=torch.int64),
#  85789: tensor([], device='cuda:0', dtype=torch.int64),
#  36615: tensor([], device='cuda:0', dtype=torch.int64),
#  85423: tensor([], device='cuda:0', dtype=torch.int64),
#  58154: tensor([], device='cuda:0', dtype=torch.int64),
#  99431: tensor([], device='cuda:0', dtype=torch.int64),
#  67546: tensor([], device='cuda:0', dtype=torch.int64),
#  3379: tensor([], device='cuda:0', dtype=torch.int64),
#  59858: tensor([], device='cuda:0', dtype=torch.int64),
#  34012: tensor([], device='cuda:0', dtype=torch.int64),
#  45178: tensor([], device='cuda:0', dtype=torch.int64),
#  91594: tensor([], device='cuda:0', dtype=torch.int64),
#  63677: tensor([], device='cuda:0', dtype=torch.int64),
#  5031: tensor([], device='cuda:0', dtype=torch.int64),
#  37492: tensor([], device='cuda:0', dtype=torch.int64),
#  68343: tensor([], device='cuda:0', dtype=torch.int64),
#  42313: tensor([], device='cuda:0', dtype=torch.int64),
#  47921: tensor([], device='cuda:0', dtype=torch.int64),
#  17612: tensor([], device='cuda:0', dtype=torch.int64),
#  37871: tensor([], device='cuda:0', dtype=torch.int64),
#  25848: tensor([], device='cuda:0', dtype=torch.int64),
#  80297: tensor([], device='cuda:0', dtype=torch.int64),
#  58714: tensor([], device='cuda:0', dtype=torch.int64),
#  69713: tensor([], device='cuda:0', dtype=torch.int64),
#  79024: tensor([], device='cuda:0', dtype=torch.int64),
#  7694: tensor([], device='cuda:0', dtype=torch.int64),
#  41994: tensor([], device='cuda:0', dtype=torch.int64),
#  15354: tensor([], device='cuda:0', dtype=torch.int64),
#  92942: tensor([], device='cuda:0', dtype=torch.int64),
#  72052: tensor([], device='cuda:0', dtype=torch.int64),
#  57834: tensor([], device='cuda:0', dtype=torch.int64),
#  74562: tensor([], device='cuda:0', dtype=torch.int64),
#  58773: tensor([], device='cuda:0', dtype=torch.int64),
#  19714: tensor([], device='cuda:0', dtype=torch.int64),
#  86341: tensor([], device='cuda:0', dtype=torch.int64),
#  54207: tensor([], device='cuda:0', dtype=torch.int64),
#  64510: tensor([], device='cuda:0', dtype=torch.int64),
#  44757: tensor([], device='cuda:0', dtype=torch.int64),
#  4199: tensor([], device='cuda:0', dtype=torch.int64),
#  56911: tensor([], device='cuda:0', dtype=torch.int64),
#  2739: tensor([], device='cuda:0', dtype=torch.int64),
#  87555: tensor([], device='cuda:0', dtype=torch.int64),
#  10269: tensor([], device='cuda:0', dtype=torch.int64),
#  53833: tensor([84513, 68107, 64278, 98977, 53833, 93979, 95976, 87187, 49292, 47336,
#          77401, 86197, 64763, 32860, 99489, 51344, 24616, 59843, 50393, 95362],
#         device='cuda:0'),
#  48176: tensor([], device='cuda:0', dtype=torch.int64),
#  77764: tensor([], device='cuda:0', dtype=torch.int64),
#  56695: tensor([], device='cuda:0', dtype=torch.int64),
#  74495: tensor([], device='cuda:0', dtype=torch.int64),
#  52747: tensor([], device='cuda:0', dtype=torch.int64),
#  47607: tensor([], device='cuda:0', dtype=torch.int64),
#  14310: tensor([], device='cuda:0', dtype=torch.int64),
#  20134: tensor([], device='cuda:0', dtype=torch.int64),
#  77656: tensor([], device='cuda:0', dtype=torch.int64),
#  2225: tensor([], device='cuda:0', dtype=torch.int64),
#  60719: tensor([], device='cuda:0', dtype=torch.int64),
#  65171: tensor([], device='cuda:0', dtype=torch.int64),
#  70491: tensor([], device='cuda:0', dtype=torch.int64),
#  54170: tensor([], device='cuda:0', dtype=torch.int64),
#  84693: tensor([], device='cuda:0', dtype=torch.int64),
#  5146: tensor([], device='cuda:0', dtype=torch.int64),
#  20465: tensor([], device='cuda:0', dtype=torch.int64),
#  84265: tensor([], device='cuda:0', dtype=torch.int64),
#  6307: tensor([], device='cuda:0', dtype=torch.int64),
#  40815: tensor([], device='cuda:0', dtype=torch.int64),
#  86599: tensor([], device='cuda:0', dtype=torch.int64),
#  39756: tensor([], device='cuda:0', dtype=torch.int64),
#  73426: tensor([], device='cuda:0', dtype=torch.int64),
#  71743: tensor([], device='cuda:0', dtype=torch.int64),
#  89108: tensor([], device='cuda:0', dtype=torch.int64),
#  78593: tensor([], device='cuda:0', dtype=torch.int64),
#  77732: tensor([], device='cuda:0', dtype=torch.int64),
#  86834: tensor([], device='cuda:0', dtype=torch.int64),
#  69392: tensor([], device='cuda:0', dtype=torch.int64),
#  101848: tensor([], device='cuda:0', dtype=torch.int64),
#  20472: tensor([], device='cuda:0', dtype=torch.int64),
#  69592: tensor([], device='cuda:0', dtype=torch.int64),
#  96614: tensor([], device='cuda:0', dtype=torch.int64),
#  9627: tensor([], device='cuda:0', dtype=torch.int64),
#  16472: tensor([], device='cuda:0', dtype=torch.int64),
#  41871: tensor([], device='cuda:0', dtype=torch.int64),
#  51084: tensor([], device='cuda:0', dtype=torch.int64),
#  76023: tensor([], device='cuda:0', dtype=torch.int64),
#  83989: tensor([], device='cuda:0', dtype=torch.int64),
#  74720: tensor([], device='cuda:0', dtype=torch.int64),
#  87706: tensor([], device='cuda:0', dtype=torch.int64),
#  79520: tensor([], device='cuda:0', dtype=torch.int64),
#  13635: tensor([], device='cuda:0', dtype=torch.int64),
#  65361: tensor([], device='cuda:0', dtype=torch.int64),
#  74224: tensor([], device='cuda:0', dtype=torch.int64),
#  89793: tensor([], device='cuda:0', dtype=torch.int64),
#  21669: tensor([], device='cuda:0', dtype=torch.int64),
#  31896: tensor([], device='cuda:0', dtype=torch.int64),
#  70366: tensor([], device='cuda:0', dtype=torch.int64),
#  13382: tensor([], device='cuda:0', dtype=torch.int64),
#  73592: tensor([], device='cuda:0', dtype=torch.int64),
#  53250: tensor([], device='cuda:0', dtype=torch.int64),
#  103479: tensor([], device='cuda:0', dtype=torch.int64),
#  56057: tensor([], device='cuda:0', dtype=torch.int64),
#  92775: tensor([], device='cuda:0', dtype=torch.int64),
#  60658: tensor([], device='cuda:0', dtype=torch.int64),
#  18249: tensor([], device='cuda:0', dtype=torch.int64),
#  99730: tensor([], device='cuda:0', dtype=torch.int64),
#  65763: tensor([], device='cuda:0', dtype=torch.int64),
#  43365: tensor([], device='cuda:0', dtype=torch.int64),
#  67521: tensor([], device='cuda:0', dtype=torch.int64),
#  96070: tensor([], device='cuda:0', dtype=torch.int64),
#  14011: tensor([], device='cuda:0', dtype=torch.int64),
#  50203: tensor([], device='cuda:0', dtype=torch.int64),
#  93527: tensor([], device='cuda:0', dtype=torch.int64),
#  2438: tensor([], device='cuda:0', dtype=torch.int64),
#  96357: tensor([], device='cuda:0', dtype=torch.int64),
#  36978: tensor([], device='cuda:0', dtype=torch.int64),
#  67887: tensor([], device='cuda:0', dtype=torch.int64),
#  28469: tensor([], device='cuda:0', dtype=torch.int64),
#  657: tensor([], device='cuda:0', dtype=torch.int64),
#  10583: tensor([], device='cuda:0', dtype=torch.int64),
#  93105: tensor([], device='cuda:0', dtype=torch.int64),
#  62086: tensor([], device='cuda:0', dtype=torch.int64),
#  97545: tensor([], device='cuda:0', dtype=torch.int64),
#  38376: tensor([], device='cuda:0', dtype=torch.int64),
#  76414: tensor([], device='cuda:0', dtype=torch.int64),
#  67378: tensor([], device='cuda:0', dtype=torch.int64),
#  97601: tensor([], device='cuda:0', dtype=torch.int64),
#  21492: tensor([102672,  98309,  28398,  43232,  52205,  46679,  35665,  65559,  64199,
#            3990,  27397,  51666,  73811, 101942,  56522,  68998,   3351,  71830,
#           37973,  76401], device='cuda:0'),
#  1777: tensor([], device='cuda:0', dtype=torch.int64),
#  47024: tensor([], device='cuda:0', dtype=torch.int64),
#  68421: tensor([], device='cuda:0', dtype=torch.int64),
#  21246: tensor([], device='cuda:0', dtype=torch.int64),
#  56702: tensor([], device='cuda:0', dtype=torch.int64),
#  102431: tensor([], device='cuda:0', dtype=torch.int64),
#  37882: tensor([], device='cuda:0', dtype=torch.int64),
#  2196: tensor([], device='cuda:0', dtype=torch.int64),
#  2155: tensor([], device='cuda:0', dtype=torch.int64),
#  84988: tensor([], device='cuda:0', dtype=torch.int64),
#  25339: tensor([], device='cuda:0', dtype=torch.int64),
#  73405: tensor([], device='cuda:0', dtype=torch.int64),
#  45499: tensor([], device='cuda:0', dtype=torch.int64),
#  89759: tensor([], device='cuda:0', dtype=torch.int64),
#  73448: tensor([], device='cuda:0', dtype=torch.int64),
#  87693: tensor([], device='cuda:0', dtype=torch.int64),
#  74272: tensor([], device='cuda:0', dtype=torch.int64),
#  94110: tensor([], device='cuda:0', dtype=torch.int64),
#  2807: tensor([], device='cuda:0', dtype=torch.int64),
#  97475: tensor([], device='cuda:0', dtype=torch.int64),
#  3028: tensor([], device='cuda:0', dtype=torch.int64),
#  98155: tensor([], device='cuda:0', dtype=torch.int64),
#  26706: tensor([], device='cuda:0', dtype=torch.int64),
#  576: tensor([], device='cuda:0', dtype=torch.int64),
#  42323: tensor([], device='cuda:0', dtype=torch.int64),
#  2413: tensor([], device='cuda:0', dtype=torch.int64),
#  77437: tensor([], device='cuda:0', dtype=torch.int64),
#  45734: tensor([], device='cuda:0', dtype=torch.int64),
#  29891: tensor([], device='cuda:0', dtype=torch.int64),
#  45805: tensor([], device='cuda:0', dtype=torch.int64),
#  58717: tensor([], device='cuda:0', dtype=torch.int64),
#  68989: tensor([], device='cuda:0', dtype=torch.int64),
#  64081: tensor([], device='cuda:0', dtype=torch.int64),
#  10098: tensor([], device='cuda:0', dtype=torch.int64),
#  65165: tensor([], device='cuda:0', dtype=torch.int64),
#  47122: tensor([], device='cuda:0', dtype=torch.int64),
#  32238: tensor([], device='cuda:0', dtype=torch.int64),
#  23824: tensor([], device='cuda:0', dtype=torch.int64),
#  90647: tensor([], device='cuda:0', dtype=torch.int64),
#  32426: tensor([], device='cuda:0', dtype=torch.int64),
#  17475: tensor([], device='cuda:0', dtype=torch.int64),
#  56058: tensor([], device='cuda:0', dtype=torch.int64),
#  59903: tensor([], device='cuda:0', dtype=torch.int64),
#  29181: tensor([], device='cuda:0', dtype=torch.int64),
#  75217: tensor([], device='cuda:0', dtype=torch.int64),
#  23818: tensor([], device='cuda:0', dtype=torch.int64),
#  96930: tensor([], device='cuda:0', dtype=torch.int64),
#  35548: tensor([], device='cuda:0', dtype=torch.int64),
#  12378: tensor([], device='cuda:0', dtype=torch.int64),
#  2664: tensor([], device='cuda:0', dtype=torch.int64),
#  99258: tensor([], device='cuda:0', dtype=torch.int64),
#  87694: tensor([], device='cuda:0', dtype=torch.int64),
#  54379: tensor([], device='cuda:0', dtype=torch.int64),
#  68489: tensor([], device='cuda:0', dtype=torch.int64),
#  60242: tensor([], device='cuda:0', dtype=torch.int64),
#  69613: tensor([], device='cuda:0', dtype=torch.int64),
#  23119: tensor([], device='cuda:0', dtype=torch.int64),
#  33340: tensor([], device='cuda:0', dtype=torch.int64),
#  3825: tensor([], device='cuda:0', dtype=torch.int64),
#  74764: tensor([], device='cuda:0', dtype=torch.int64),
#  86510: tensor([], device='cuda:0', dtype=torch.int64),
#  15882: tensor([], device='cuda:0', dtype=torch.int64),
#  76212: tensor([], device='cuda:0', dtype=torch.int64),
#  86590: tensor([], device='cuda:0', dtype=torch.int64),
#  70180: tensor([], device='cuda:0', dtype=torch.int64),
#  37174: tensor([], device='cuda:0', dtype=torch.int64),
#  82207: tensor([], device='cuda:0', dtype=torch.int64),
#  11151: tensor([], device='cuda:0', dtype=torch.int64),
#  84325: tensor([], device='cuda:0', dtype=torch.int64),
#  80305: tensor([], device='cuda:0', dtype=torch.int64),
#  82673: tensor([], device='cuda:0', dtype=torch.int64),
#  74815: tensor([], device='cuda:0', dtype=torch.int64),
#  56059: tensor([ 51935,  62726,   2166,  61938,  26887, 101756, 102265,  51443,  74262,
#           56059,  64836,  68341,  27623,  63596,  93488, 101113,  86894,  94596,
#           75535,  17328], device='cuda:0'),
#  69383: tensor([], device='cuda:0', dtype=torch.int64),
#  178: tensor([], device='cuda:0', dtype=torch.int64),
#  69029: tensor([], device='cuda:0', dtype=torch.int64),
#  71252: tensor([ 88779,  44040,  99868,  86016,  51856,  83506, 100885,  94240,  72432,
#           97936,  68573,  44585,  98828,  82552,  12524,  90048,  19574,  53712,
#           82149,  94016], device='cuda:0'),
#  90415: tensor([], device='cuda:0', dtype=torch.int64),
#  1484: tensor([], device='cuda:0', dtype=torch.int64),
#  10109: tensor([], device='cuda:0', dtype=torch.int64),
#  75162: tensor([], device='cuda:0', dtype=torch.int64),
#  53830: tensor([], device='cuda:0', dtype=torch.int64),
#  69390: tensor([], device='cuda:0', dtype=torch.int64),
#  91472: tensor([], device='cuda:0', dtype=torch.int64),
#  74464: tensor([], device='cuda:0', dtype=torch.int64),
#  27405: tensor([], device='cuda:0', dtype=torch.int64),
#  6803: tensor([], device='cuda:0', dtype=torch.int64),
#  1554: tensor([], device='cuda:0', dtype=torch.int64),
#  66345: tensor([], device='cuda:0', dtype=torch.int64),
#  76224: tensor([], device='cuda:0', dtype=torch.int64),
#  90503: tensor([], device='cuda:0', dtype=torch.int64),
#  10323: tensor([], device='cuda:0', dtype=torch.int64),
#  49501: tensor([], device='cuda:0', dtype=torch.int64),
#  60053: tensor([], device='cuda:0', dtype=torch.int64),
#  81293: tensor([], device='cuda:0', dtype=torch.int64),
#  30225: tensor([], device='cuda:0', dtype=torch.int64),
#  95731: tensor([], device='cuda:0', dtype=torch.int64),
#  62307: tensor([], device='cuda:0', dtype=torch.int64),
#  91173: tensor([], device='cuda:0', dtype=torch.int64),
#  76168: tensor([], device='cuda:0', dtype=torch.int64),
#  66789: tensor([], device='cuda:0', dtype=torch.int64),
#  76725: tensor([], device='cuda:0', dtype=torch.int64),
#  70609: tensor([], device='cuda:0', dtype=torch.int64),
#  70904: tensor([], device='cuda:0', dtype=torch.int64),
#  77756: tensor([], device='cuda:0', dtype=torch.int64),
#  102080: tensor([], device='cuda:0', dtype=torch.int64),
#  13998: tensor([], device='cuda:0', dtype=torch.int64),
#  26019: tensor([], device='cuda:0', dtype=torch.int64),
#  65818: tensor([], device='cuda:0', dtype=torch.int64),
#  15515: tensor([], device='cuda:0', dtype=torch.int64),
#  78520: tensor([], device='cuda:0', dtype=torch.int64),
#  13640: tensor([99693, 53946, 45328, 50129, 93739, 53729, 69019, 67494,  1490, 47164,
#          72709, 20011, 82179, 96879, 48619, 97256, 18602, 14011, 13664, 30100],
#         device='cuda:0'),
#  16930: tensor([], device='cuda:0', dtype=torch.int64),
#  70777: tensor([], device='cuda:0', dtype=torch.int64),
#  94014: tensor([], device='cuda:0', dtype=torch.int64),
#  70738: tensor([], device='cuda:0', dtype=torch.int64),
#  96927: tensor([], device='cuda:0', dtype=torch.int64),
#  53816: tensor([], device='cuda:0', dtype=torch.int64),
#  43781: tensor([], device='cuda:0', dtype=torch.int64),
#  91620: tensor([], device='cuda:0', dtype=torch.int64),
#  83889: tensor([], device='cuda:0', dtype=torch.int64),
#  37126: tensor([], device='cuda:0', dtype=torch.int64),
#  81870: tensor([], device='cuda:0', dtype=torch.int64),
#  57729: tensor([], device='cuda:0', dtype=torch.int64),
#  90361: tensor([], device='cuda:0', dtype=torch.int64),
#  39517: tensor([], device='cuda:0', dtype=torch.int64),
#  86640: tensor([], device='cuda:0', dtype=torch.int64),
#  63468: tensor([], device='cuda:0', dtype=torch.int64),
#  69369: tensor([], device='cuda:0', dtype=torch.int64),
#  46669: tensor([], device='cuda:0', dtype=torch.int64),
#  99171: tensor([], device='cuda:0', dtype=torch.int64),
#  31805: tensor([], device='cuda:0', dtype=torch.int64),
#  49331: tensor([], device='cuda:0', dtype=torch.int64),
#  73987: tensor([], device='cuda:0', dtype=torch.int64),
#  4182: tensor([], device='cuda:0', dtype=torch.int64),
#  92249: tensor([], device='cuda:0', dtype=torch.int64),
#  24387: tensor([], device='cuda:0', dtype=torch.int64),
#  4990: tensor([], device='cuda:0', dtype=torch.int64),
#  98283: tensor([], device='cuda:0', dtype=torch.int64),
#  8887: tensor([], device='cuda:0', dtype=torch.int64),
#  86390: tensor([], device='cuda:0', dtype=torch.int64),
#  90233: tensor([], device='cuda:0', dtype=torch.int64),
#  49762: tensor([], device='cuda:0', dtype=torch.int64),
#  58497: tensor([], device='cuda:0', dtype=torch.int64),
#  80315: tensor([], device='cuda:0', dtype=torch.int64),
#  91046: tensor([], device='cuda:0', dtype=torch.int64),
#  24724: tensor([], device='cuda:0', dtype=torch.int64),
#  46799: tensor([], device='cuda:0', dtype=torch.int64),
#  69708: tensor([], device='cuda:0', dtype=torch.int64),
#  9951: tensor([], device='cuda:0', dtype=torch.int64),
#  50219: tensor([], device='cuda:0', dtype=torch.int64),
#  89079: tensor([], device='cuda:0', dtype=torch.int64),
#  60624: tensor([], device='cuda:0', dtype=torch.int64),
#  58155: tensor([], device='cuda:0', dtype=torch.int64),
#  30728: tensor([], device='cuda:0', dtype=torch.int64),
#  8173: tensor([], device='cuda:0', dtype=torch.int64),
#  2198: tensor([], device='cuda:0', dtype=torch.int64),
#  59850: tensor([], device='cuda:0', dtype=torch.int64),
#  89730: tensor([], device='cuda:0', dtype=torch.int64),
#  85738: tensor([], device='cuda:0', dtype=torch.int64),
#  101977: tensor([], device='cuda:0', dtype=torch.int64),
#  54865: tensor([], device='cuda:0', dtype=torch.int64),
#  53849: tensor([], device='cuda:0', dtype=torch.int64),
#  39005: tensor([], device='cuda:0', dtype=torch.int64),
#  49298: tensor([], device='cuda:0', dtype=torch.int64),
#  48171: tensor([], device='cuda:0', dtype=torch.int64),
#  24410: tensor([], device='cuda:0', dtype=torch.int64),
#  22224: tensor([], device='cuda:0', dtype=torch.int64),
#  10585: tensor([], device='cuda:0', dtype=torch.int64),
#  2193: tensor([], device='cuda:0', dtype=torch.int64),
#  55089: tensor([], device='cuda:0', dtype=torch.int64),
#  69594: tensor([], device='cuda:0', dtype=torch.int64),
#  59573: tensor([], device='cuda:0', dtype=torch.int64),
#  84416: tensor([], device='cuda:0', dtype=torch.int64),
#  78016: tensor([], device='cuda:0', dtype=torch.int64),
#  75151: tensor([], device='cuda:0', dtype=torch.int64),
#  50481: tensor([], device='cuda:0', dtype=torch.int64),
#  92049: tensor([], device='cuda:0', dtype=torch.int64),
#  96612: tensor([], device='cuda:0', dtype=torch.int64),
#  92449: tensor([], device='cuda:0', dtype=torch.int64),
#  85870: tensor([], device='cuda:0', dtype=torch.int64),
#  68506: tensor([], device='cuda:0', dtype=torch.int64),
#  71470: tensor([], device='cuda:0', dtype=torch.int64),
#  97184: tensor([], device='cuda:0', dtype=torch.int64),
#  77626: tensor([], device='cuda:0', dtype=torch.int64),
#  17069: tensor([], device='cuda:0', dtype=torch.int64),
#  77387: tensor([], device='cuda:0', dtype=torch.int64),
#  20523: tensor([], device='cuda:0', dtype=torch.int64),
#  56937: tensor([], device='cuda:0', dtype=torch.int64),
#  4989: tensor([], device='cuda:0', dtype=torch.int64),
#  33619: tensor([], device='cuda:0', dtype=torch.int64),
#  78380: tensor([], device='cuda:0', dtype=torch.int64),
#  42659: tensor([], device='cuda:0', dtype=torch.int64),
#  92432: tensor([], device='cuda:0', dtype=torch.int64),
#  14306: tensor([], device='cuda:0', dtype=torch.int64),
#  46070: tensor([], device='cuda:0', dtype=torch.int64),
#  56052: tensor([], device='cuda:0', dtype=torch.int64),
#  70762: tensor([], device='cuda:0', dtype=torch.int64),
#  36394: tensor([], device='cuda:0', dtype=torch.int64),
#  93908: tensor([], device='cuda:0', dtype=torch.int64),
#  24833: tensor([], device='cuda:0', dtype=torch.int64),
#  104219: tensor([], device='cuda:0', dtype=torch.int64),
#  16205: tensor([], device='cuda:0', dtype=torch.int64),
#  90727: tensor([], device='cuda:0', dtype=torch.int64),
#  54245: tensor([], device='cuda:0', dtype=torch.int64),
#  51986: tensor([], device='cuda:0', dtype=torch.int64),
#  48127: tensor([], device='cuda:0', dtype=torch.int64),
#  88507: tensor([], device='cuda:0', dtype=torch.int64),
#  48153: tensor([], device='cuda:0', dtype=torch.int64),
#  69978: tensor([], device='cuda:0', dtype=torch.int64),
#  27601: tensor([], device='cuda:0', dtype=torch.int64),
#  9748: tensor([], device='cuda:0', dtype=torch.int64),
#  15937: tensor([], device='cuda:0', dtype=torch.int64),
#  75826: tensor([], device='cuda:0', dtype=torch.int64),
#  38364: tensor([], device='cuda:0', dtype=torch.int64),
#  57613: tensor([], device='cuda:0', dtype=torch.int64),
#  70841: tensor([], device='cuda:0', dtype=torch.int64),
#  69586: tensor([], device='cuda:0', dtype=torch.int64),
#  81774: tensor([], device='cuda:0', dtype=torch.int64),
#  46560: tensor([], device='cuda:0', dtype=torch.int64),
#  73297: tensor([], device='cuda:0', dtype=torch.int64),
#  489: tensor([], device='cuda:0', dtype=torch.int64),
#  79896: tensor([], device='cuda:0', dtype=torch.int64),
#  54307: tensor([], device='cuda:0', dtype=torch.int64),
#  93641: tensor([], device='cuda:0', dtype=torch.int64),
#  90672: tensor([], device='cuda:0', dtype=torch.int64),
#  16731: tensor([], device='cuda:0', dtype=torch.int64),
#  65864: tensor([], device='cuda:0', dtype=torch.int64),
#  57537: tensor([], device='cuda:0', dtype=torch.int64),
#  1032: tensor([], device='cuda:0', dtype=torch.int64),
#  53247: tensor([], device='cuda:0', dtype=torch.int64),
#  61611: tensor([], device='cuda:0', dtype=torch.int64),
#  83691: tensor([], device='cuda:0', dtype=torch.int64),
#  45713: tensor([], device='cuda:0', dtype=torch.int64),
#  42417: tensor([], device='cuda:0', dtype=torch.int64),
#  45763: tensor([], device='cuda:0', dtype=torch.int64),
#  55531: tensor([], device='cuda:0', dtype=torch.int64),
#  33559: tensor([], device='cuda:0', dtype=torch.int64),
#  61812: tensor([], device='cuda:0', dtype=torch.int64),
#  62204: tensor([], device='cuda:0', dtype=torch.int64),
#  72036: tensor([], device='cuda:0', dtype=torch.int64),
#  90985: tensor([], device='cuda:0', dtype=torch.int64),
#  77147: tensor([], device='cuda:0', dtype=torch.int64),
#  2663: tensor([], device='cuda:0', dtype=torch.int64),
#  26532: tensor([], device='cuda:0', dtype=torch.int64),
#  50503: tensor([], device='cuda:0', dtype=torch.int64),
#  23826: tensor([], device='cuda:0', dtype=torch.int64),
#  87467: tensor([], device='cuda:0', dtype=torch.int64),
#  71898: tensor([], device='cuda:0', dtype=torch.int64),
#  52759: tensor([], device='cuda:0', dtype=torch.int64),
#  76203: tensor([], device='cuda:0', dtype=torch.int64),
#  93387: tensor([], device='cuda:0', dtype=torch.int64),
#  52240: tensor([], device='cuda:0', dtype=torch.int64),
#  67891: tensor([], device='cuda:0', dtype=torch.int64),
#  16852: tensor([], device='cuda:0', dtype=torch.int64),
#  80447: tensor([], device='cuda:0', dtype=torch.int64),
#  89156: tensor([], device='cuda:0', dtype=torch.int64),
#  76363: tensor([], device='cuda:0', dtype=torch.int64),
#  3514: tensor([], device='cuda:0', dtype=torch.int64),
#  38731: tensor([], device='cuda:0', dtype=torch.int64),
#  65777: tensor([], device='cuda:0', dtype=torch.int64),
#  87763: tensor([], device='cuda:0', dtype=torch.int64),
#  81995: tensor([], device='cuda:0', dtype=torch.int64),
#  17320: tensor([], device='cuda:0', dtype=torch.int64),
#  39247: tensor([], device='cuda:0', dtype=torch.int64),
#  16521: tensor([], device='cuda:0', dtype=torch.int64),
#  2169: tensor([], device='cuda:0', dtype=torch.int64),
#  46787: tensor([], device='cuda:0', dtype=torch.int64),
#  87486: tensor([], device='cuda:0', dtype=torch.int64),
#  78194: tensor([], device='cuda:0', dtype=torch.int64),
#  61194: tensor([], device='cuda:0', dtype=torch.int64),
#  69463: tensor([], device='cuda:0', dtype=torch.int64),
#  25049: tensor([], device='cuda:0', dtype=torch.int64),
#  259: tensor([], device='cuda:0', dtype=torch.int64),
#  56418: tensor([], device='cuda:0', dtype=torch.int64),
#  38664: tensor([], device='cuda:0', dtype=torch.int64),
#  8365: tensor([], device='cuda:0', dtype=torch.int64),
#  84929: tensor([], device='cuda:0', dtype=torch.int64),
#  10995: tensor([], device='cuda:0', dtype=torch.int64),
#  81088: tensor([], device='cuda:0', dtype=torch.int64),
#  44496: tensor([], device='cuda:0', dtype=torch.int64),
#  6546: tensor([], device='cuda:0', dtype=torch.int64),
#  2195: tensor([], device='cuda:0', dtype=torch.int64),
#  43173: tensor([], device='cuda:0', dtype=torch.int64),
#  55335: tensor([], device='cuda:0', dtype=torch.int64),
#  26062: tensor([80209, 71084, 47966, 58413, 82401,  3937, 11028, 17595, 43469, 80072,
#          26062, 98243, 15698,  3599, 81192, 79891, 41051, 40829, 90875, 76212],
#         device='cuda:0'),
#  55085: tensor([], device='cuda:0', dtype=torch.int64),
#  14020: tensor([], device='cuda:0', dtype=torch.int64),
#  17793: tensor([], device='cuda:0', dtype=torch.int64),
#  33181: tensor([], device='cuda:0', dtype=torch.int64),
#  77798: tensor([], device='cuda:0', dtype=torch.int64),
#  59230: tensor([], device='cuda:0', dtype=torch.int64),
#  23555: tensor([], device='cuda:0', dtype=torch.int64),
#  6511: tensor([], device='cuda:0', dtype=torch.int64),
#  94163: tensor([], device='cuda:0', dtype=torch.int64),
#  64368: tensor([], device='cuda:0', dtype=torch.int64),
#  84510: tensor([], device='cuda:0', dtype=torch.int64),
#  89845: tensor([], device='cuda:0', dtype=torch.int64),
#  66998: tensor([], device='cuda:0', dtype=torch.int64),
#  69287: tensor([], device='cuda:0', dtype=torch.int64),
#  41204: tensor([], device='cuda:0', dtype=torch.int64),
#  58236: tensor([], device='cuda:0', dtype=torch.int64),
#  65096: tensor([], device='cuda:0', dtype=torch.int64),
#  53401: tensor([], device='cuda:0', dtype=torch.int64),
#  88232: tensor([], device='cuda:0', dtype=torch.int64),
#  86991: tensor([], device='cuda:0', dtype=torch.int64),
#  71900: tensor([], device='cuda:0', dtype=torch.int64),
#  18170: tensor([], device='cuda:0', dtype=torch.int64),
#  97171: tensor([], device='cuda:0', dtype=torch.int64),
#  66275: tensor([], device='cuda:0', dtype=torch.int64),
#  93764: tensor([], device='cuda:0', dtype=torch.int64),
#  52665: tensor([], device='cuda:0', dtype=torch.int64),
#  33464: tensor([], device='cuda:0', dtype=torch.int64),
#  76321: tensor([], device='cuda:0', dtype=torch.int64),
#  93430: tensor([], device='cuda:0', dtype=torch.int64),
#  58881: tensor([], device='cuda:0', dtype=torch.int64),
#  2787: tensor([], device='cuda:0', dtype=torch.int64),
#  35537: tensor([], device='cuda:0', dtype=torch.int64),
#  17074: tensor([], device='cuda:0', dtype=torch.int64),
#  2162: tensor([], device='cuda:0', dtype=torch.int64),
#  69591: tensor([], device='cuda:0', dtype=torch.int64),
#  68065: tensor([], device='cuda:0', dtype=torch.int64),
#  3516: tensor([], device='cuda:0', dtype=torch.int64),
#  1685: tensor([], device='cuda:0', dtype=torch.int64),
#  90669: tensor([], device='cuda:0', dtype=torch.int64),
#  48165: tensor([], device='cuda:0', dtype=torch.int64),
#  49992: tensor([], device='cuda:0', dtype=torch.int64),
#  57192: tensor([], device='cuda:0', dtype=torch.int64),
#  46951: tensor([], device='cuda:0', dtype=torch.int64),
#  76549: tensor([], device='cuda:0', dtype=torch.int64),
#  24655: tensor([], device='cuda:0', dtype=torch.int64),
#  17565: tensor([], device='cuda:0', dtype=torch.int64),
#  66191: tensor([], device='cuda:0', dtype=torch.int64),
#  74678: tensor([], device='cuda:0', dtype=torch.int64),
#  14554: tensor([], device='cuda:0', dtype=torch.int64),
#  43242: tensor([], device='cuda:0', dtype=torch.int64),
#  14865: tensor([], device='cuda:0', dtype=torch.int64),
#  65395: tensor([], device='cuda:0', dtype=torch.int64),
#  19422: tensor([], device='cuda:0', dtype=torch.int64),
#  58404: tensor([], device='cuda:0', dtype=torch.int64),
#  72731: tensor([], device='cuda:0', dtype=torch.int64),
#  56274: tensor([], device='cuda:0', dtype=torch.int64),
#  21104: tensor([], device='cuda:0', dtype=torch.int64),
#  44797: tensor([], device='cuda:0', dtype=torch.int64),
#  43761: tensor([], device='cuda:0', dtype=torch.int64),
#  60715: tensor([], device='cuda:0', dtype=torch.int64),
#  48532: tensor([], device='cuda:0', dtype=torch.int64),
#  68507: tensor([], device='cuda:0', dtype=torch.int64),
#  86628: tensor([], device='cuda:0', dtype=torch.int64),
#  59107: tensor([], device='cuda:0', dtype=torch.int64),
#  69495: tensor([], device='cuda:0', dtype=torch.int64),
#  52072: tensor([], device='cuda:0', dtype=torch.int64),
#  91897: tensor([], device='cuda:0', dtype=torch.int64),
#  100194: tensor([], device='cuda:0', dtype=torch.int64),
#  89193: tensor([], device='cuda:0', dtype=torch.int64),
#  60629: tensor([], device='cuda:0', dtype=torch.int64),
#  32770: tensor([], device='cuda:0', dtype=torch.int64),
#  31206: tensor([], device='cuda:0', dtype=torch.int64),
#  86821: tensor([], device='cuda:0', dtype=torch.int64),
#  28915: tensor([], device='cuda:0', dtype=torch.int64),
#  50493: tensor([], device='cuda:0', dtype=torch.int64),
#  82576: tensor([], device='cuda:0', dtype=torch.int64),
#  83372: tensor([], device='cuda:0', dtype=torch.int64),
#  10326: tensor([], device='cuda:0', dtype=torch.int64),
#  67226: tensor([], device='cuda:0', dtype=torch.int64),
#  7155: tensor([], device='cuda:0', dtype=torch.int64),
#  83112: tensor([], device='cuda:0', dtype=torch.int64),
#  19697: tensor([], device='cuda:0', dtype=torch.int64),
#  12524: tensor([], device='cuda:0', dtype=torch.int64),
#  21024: tensor([], device='cuda:0', dtype=torch.int64),
#  32798: tensor([], device='cuda:0', dtype=torch.int64),
#  40595: tensor([], device='cuda:0', dtype=torch.int64),
#  24381: tensor([], device='cuda:0', dtype=torch.int64),
#  57489: tensor([], device='cuda:0', dtype=torch.int64),
#  62772: tensor([], device='cuda:0', dtype=torch.int64),
#  89249: tensor([], device='cuda:0', dtype=torch.int64),
#  38656: tensor([], device='cuda:0', dtype=torch.int64),
#  65774: tensor([], device='cuda:0', dtype=torch.int64),
#  42466: tensor([], device='cuda:0', dtype=torch.int64),
#  54112: tensor([], device='cuda:0', dtype=torch.int64),
#  23615: tensor([], device='cuda:0', dtype=torch.int64),
#  53878: tensor([], device='cuda:0', dtype=torch.int64),
#  17598: tensor([], device='cuda:0', dtype=torch.int64),
#  1667: tensor([], device='cuda:0', dtype=torch.int64),
#  13496: tensor([], device='cuda:0', dtype=torch.int64),
#  82110: tensor([], device='cuda:0', dtype=torch.int64),
#  60329: tensor([], device='cuda:0', dtype=torch.int64),
#  2151: tensor([], device='cuda:0', dtype=torch.int64),
#  69612: tensor([], device='cuda:0', dtype=torch.int64),
#  60426: tensor([], device='cuda:0', dtype=torch.int64),
#  82111: tensor([], device='cuda:0', dtype=torch.int64),
#  92763: tensor([], device='cuda:0', dtype=torch.int64),
#  50864: tensor([], device='cuda:0', dtype=torch.int64),
#  46432: tensor([], device='cuda:0', dtype=torch.int64),
#  95138: tensor([], device='cuda:0', dtype=torch.int64),
#  37968: tensor([], device='cuda:0', dtype=torch.int64),
#  81058: tensor([], device='cuda:0', dtype=torch.int64),
#  70064: tensor([], device='cuda:0', dtype=torch.int64),
#  70564: tensor([], device='cuda:0', dtype=torch.int64),
#  38000: tensor([], device='cuda:0', dtype=torch.int64),
#  93278: tensor([], device='cuda:0', dtype=torch.int64),
#  39737: tensor([], device='cuda:0', dtype=torch.int64),
#  1242: tensor([], device='cuda:0', dtype=torch.int64),
#  11258: tensor([], device='cuda:0', dtype=torch.int64),
#  1973: tensor([], device='cuda:0', dtype=torch.int64),
#  61083: tensor([], device='cuda:0', dtype=torch.int64),
#  78992: tensor([], device='cuda:0', dtype=torch.int64),
#  54079: tensor([], device='cuda:0', dtype=torch.int64),
#  68579: tensor([], device='cuda:0', dtype=torch.int64),
#  3677: tensor([], device='cuda:0', dtype=torch.int64),
#  57097: tensor([], device='cuda:0', dtype=torch.int64),
#  46232: tensor([], device='cuda:0', dtype=torch.int64),
#  35638: tensor([], device='cuda:0', dtype=torch.int64),
#  44951: tensor([], device='cuda:0', dtype=torch.int64),
#  51094: tensor([], device='cuda:0', dtype=torch.int64),
#  53208: tensor([], device='cuda:0', dtype=torch.int64),
#  4915: tensor([], device='cuda:0', dtype=torch.int64),
#  41562: tensor([], device='cuda:0', dtype=torch.int64),
#  57642: tensor([], device='cuda:0', dtype=torch.int64),
#  59408: tensor([], device='cuda:0', dtype=torch.int64),
#  85609: tensor([], device='cuda:0', dtype=torch.int64),
#  100770: tensor([], device='cuda:0', dtype=torch.int64),
#  12376: tensor([], device='cuda:0', dtype=torch.int64),
#  15696: tensor([], device='cuda:0', dtype=torch.int64),
#  95863: tensor([], device='cuda:0', dtype=torch.int64),
#  1631: tensor([], device='cuda:0', dtype=torch.int64),
#  13488: tensor([], device='cuda:0', dtype=torch.int64),
#  51461: tensor([], device='cuda:0', dtype=torch.int64),
#  85661: tensor([], device='cuda:0', dtype=torch.int64),
#  64: tensor([], device='cuda:0', dtype=torch.int64),
#  12595: tensor([], device='cuda:0', dtype=torch.int64),
#  52153: tensor([], device='cuda:0', dtype=torch.int64),
#  18811: tensor([], device='cuda:0', dtype=torch.int64),
#  64296: tensor([], device='cuda:0', dtype=torch.int64),
#  15258: tensor([], device='cuda:0', dtype=torch.int64),
#  103856: tensor([], device='cuda:0', dtype=torch.int64),
#  42022: tensor([], device='cuda:0', dtype=torch.int64),
#  7515: tensor([], device='cuda:0', dtype=torch.int64),
#  22274: tensor([], device='cuda:0', dtype=torch.int64),
#  43763: tensor([], device='cuda:0', dtype=torch.int64),
#  56653: tensor([], device='cuda:0', dtype=torch.int64),
#  40809: tensor([], device='cuda:0', dtype=torch.int64),
#  42032: tensor([], device='cuda:0', dtype=torch.int64),
#  43881: tensor([], device='cuda:0', dtype=torch.int64),
#  209: tensor([], device='cuda:0', dtype=torch.int64),
#  70783: tensor([], device='cuda:0', dtype=torch.int64),
#  20844: tensor([], device='cuda:0', dtype=torch.int64),
#  13522: tensor([], device='cuda:0', dtype=torch.int64),
#  22240: tensor([51023,  6930,  9809, 56935, 72215, 12570, 86721, 70858, 71066, 99351,
#          75547, 79750, 79263,  8215, 34895, 83505, 57186, 69922, 57759, 93095],
#         device='cuda:0'),
#  67612: tensor([], device='cuda:0', dtype=torch.int64),
#  22797: tensor([], device='cuda:0', dtype=torch.int64),
#  46781: tensor([], device='cuda:0', dtype=torch.int64),
#  103173: tensor([], device='cuda:0', dtype=torch.int64),
#  92363: tensor([], device='cuda:0', dtype=torch.int64),
#  60722: tensor([], device='cuda:0', dtype=torch.int64),
#  66813: tensor([], device='cuda:0', dtype=torch.int64),
#  22237: tensor([], device='cuda:0', dtype=torch.int64),
#  97737: tensor([], device='cuda:0', dtype=torch.int64),
#  46876: tensor([], device='cuda:0', dtype=torch.int64),
#  67517: tensor([], device='cuda:0', dtype=torch.int64),
#  99713: tensor([], device='cuda:0', dtype=torch.int64),
#  86146: tensor([], device='cuda:0', dtype=torch.int64),
#  83184: tensor([], device='cuda:0', dtype=torch.int64),
#  40032: tensor([], device='cuda:0', dtype=torch.int64),
#  67824: tensor([], device='cuda:0', dtype=torch.int64),
#  31011: tensor([], device='cuda:0', dtype=torch.int64),
#  36915: tensor([], device='cuda:0', dtype=torch.int64),
#  44214: tensor([], device='cuda:0', dtype=torch.int64),
#  72595: tensor([], device='cuda:0', dtype=torch.int64),
#  60733: tensor([], device='cuda:0', dtype=torch.int64),
#  50015: tensor([], device='cuda:0', dtype=torch.int64),
#  11226: tensor([], device='cuda:0', dtype=torch.int64),
#  9596: tensor([], device='cuda:0', dtype=torch.int64),
#  22159: tensor([], device='cuda:0', dtype=torch.int64),
#  55430: tensor([], device='cuda:0', dtype=torch.int64),
#  14675: tensor([], device='cuda:0', dtype=torch.int64),
#  14044: tensor([], device='cuda:0', dtype=torch.int64),
#  88038: tensor([], device='cuda:0', dtype=torch.int64),
#  53348: tensor([], device='cuda:0', dtype=torch.int64),
#  56486: tensor([ 54697,  52669,  79605,  59299, 103167, 100189,  43469,  97927,  70741,
#           91660,  84155,  70856,  67714,   9661,  83797,  26315, 103203,  81726,
#           76635,  89824], device='cuda:0'),
#  94919: tensor([], device='cuda:0', dtype=torch.int64),
#  13097: tensor([], device='cuda:0', dtype=torch.int64),
#  39116: tensor([], device='cuda:0', dtype=torch.int64),
#  7507: tensor([], device='cuda:0', dtype=torch.int64),
#  42353: tensor([], device='cuda:0', dtype=torch.int64),
#  44711: tensor([], device='cuda:0', dtype=torch.int64),
#  51536: tensor([], device='cuda:0', dtype=torch.int64),
#  3859: tensor([], device='cuda:0', dtype=torch.int64),
#  78904: tensor([], device='cuda:0', dtype=torch.int64),
#  36904: tensor([], device='cuda:0', dtype=torch.int64),
#  69071: tensor([], device='cuda:0', dtype=torch.int64),
#  18963: tensor([], device='cuda:0', dtype=torch.int64),
#  73986: tensor([], device='cuda:0', dtype=torch.int64),
#  85887: tensor([], device='cuda:0', dtype=torch.int64),
#  87878: tensor([], device='cuda:0', dtype=torch.int64),
#  58718: tensor([], device='cuda:0', dtype=torch.int64),
#  34637: tensor([], device='cuda:0', dtype=torch.int64),
#  73686: tensor([ 45668,  79179,  67408, 103243,  85921,  47291,  73686, 102857,  18562,
#             335,   1516,  17468,  11923,  20533,  97878,  34206,  86226, 102504,
#           42934,  75701], device='cuda:0'),
#  71730: tensor([], device='cuda:0', dtype=torch.int64),
#  86976: tensor([], device='cuda:0', dtype=torch.int64),
#  97519: tensor([], device='cuda:0', dtype=torch.int64),
#  70514: tensor([], device='cuda:0', dtype=torch.int64),
#  7699: tensor([], device='cuda:0', dtype=torch.int64),
#  76438: tensor([], device='cuda:0', dtype=torch.int64),
#  73120: tensor([], device='cuda:0', dtype=torch.int64),
#  32919: tensor([], device='cuda:0', dtype=torch.int64),
#  85689: tensor([], device='cuda:0', dtype=torch.int64),
#  2091: tensor([13487, 40383, 25796, 94116, 84482, 66352, 41692, 52258, 20952, 52377,
#          94681, 69502, 28670, 55821, 84994, 89163, 82536, 40747,  4926,  5216],
#         device='cuda:0'),
#  78752: tensor([], device='cuda:0', dtype=torch.int64),
#  64265: tensor([], device='cuda:0', dtype=torch.int64),
#  3878: tensor([], device='cuda:0', dtype=torch.int64),
#  58722: tensor([], device='cuda:0', dtype=torch.int64),
#  54593: tensor([], device='cuda:0', dtype=torch.int64),
#  56745: tensor([], device='cuda:0', dtype=torch.int64),
#  66284: tensor([], device='cuda:0', dtype=torch.int64),
#  66460: tensor([], device='cuda:0', dtype=torch.int64),
#  78666: tensor([], device='cuda:0', dtype=torch.int64),
#  65347: tensor([], device='cuda:0', dtype=torch.int64),
#  26360: tensor([], device='cuda:0', dtype=torch.int64),
#  69025: tensor([], device='cuda:0', dtype=torch.int64),
#  81946: tensor([], device='cuda:0', dtype=torch.int64),
#  91517: tensor([], device='cuda:0', dtype=torch.int64),
#  42147: tensor([], device='cuda:0', dtype=torch.int64),
#  76039: tensor([], device='cuda:0', dtype=torch.int64),
#  26490: tensor([], device='cuda:0', dtype=torch.int64),
#  3185: tensor([], device='cuda:0', dtype=torch.int64),
#  41493: tensor([], device='cuda:0', dtype=torch.int64),
#  44533: tensor([], device='cuda:0', dtype=torch.int64),
#  95170: tensor([], device='cuda:0', dtype=torch.int64),
#  45179: tensor([], device='cuda:0', dtype=torch.int64),
#  31140: tensor([], device='cuda:0', dtype=torch.int64),
#  89314: tensor([], device='cuda:0', dtype=torch.int64),
#  78012: tensor([], device='cuda:0', dtype=torch.int64),
#  48145: tensor([], device='cuda:0', dtype=torch.int64),
#  40930: tensor([], device='cuda:0', dtype=torch.int64),
#  56941: tensor([], device='cuda:0', dtype=torch.int64),
#  102854: tensor([], device='cuda:0', dtype=torch.int64),
#  77949: tensor([], device='cuda:0', dtype=torch.int64),
#  55899: tensor([], device='cuda:0', dtype=torch.int64),
#  80430: tensor([], device='cuda:0', dtype=torch.int64),
#  73541: tensor([], device='cuda:0', dtype=torch.int64),
#  1606: tensor([], device='cuda:0', dtype=torch.int64),
#  43344: tensor([], device='cuda:0', dtype=torch.int64),
#  84079: tensor([], device='cuda:0', dtype=torch.int64),
#  31883: tensor([], device='cuda:0', dtype=torch.int64),
#  78762: tensor([], device='cuda:0', dtype=torch.int64),
#  40036: tensor([], device='cuda:0', dtype=torch.int64),
#  13038: tensor([], device='cuda:0', dtype=torch.int64),
#  68977: tensor([], device='cuda:0', dtype=torch.int64),
#  8488: tensor([ 89939,  71469,  81772, 103979,  74927,  54846,  71113,  49164,   8488,
#           82466,  38437,  71483,  95842,  45370,  98631,  55717,  77836,  74527,
#           56575,  58892], device='cuda:0'),
#  99423: tensor([], device='cuda:0', dtype=torch.int64),
#  56643: tensor([], device='cuda:0', dtype=torch.int64),
#  65802: tensor([], device='cuda:0', dtype=torch.int64),
#  69830: tensor([], device='cuda:0', dtype=torch.int64),
#  60419: tensor([], device='cuda:0', dtype=torch.int64),
#  73394: tensor([], device='cuda:0', dtype=torch.int64),
#  77403: tensor([], device='cuda:0', dtype=torch.int64),
#  3334: tensor([], device='cuda:0', dtype=torch.int64),
#  82366: tensor([], device='cuda:0', dtype=torch.int64),
#  70581: tensor([], device='cuda:0', dtype=torch.int64),
#  71990: tensor([102671,    160,  98674,  69769,  17962,  54646,  60371,  51104,  24629,
#            3136,  22693,  71990,  57436,  13216,  41948,  24484,  30109,  54262,
#           79189,  36525], device='cuda:0'),
#  79067: tensor([], device='cuda:0', dtype=torch.int64),
#  40557: tensor([], device='cuda:0', dtype=torch.int64),
#  23955: tensor([], device='cuda:0', dtype=torch.int64),
#  36566: tensor([], device='cuda:0', dtype=torch.int64),
#  65741: tensor([], device='cuda:0', dtype=torch.int64),
#  93287: tensor([], device='cuda:0', dtype=torch.int64),
#  60926: tensor([], device='cuda:0', dtype=torch.int64),
#  70583: tensor([], device='cuda:0', dtype=torch.int64),
#  13449: tensor([], device='cuda:0', dtype=torch.int64),
#  70212: tensor([], device='cuda:0', dtype=torch.int64),
#  41266: tensor([], device='cuda:0', dtype=torch.int64),
#  12476: tensor([], device='cuda:0', dtype=torch.int64),
#  1052: tensor([], device='cuda:0', dtype=torch.int64),
#  100450: tensor([], device='cuda:0', dtype=torch.int64),
#  46558: tensor([], device='cuda:0', dtype=torch.int64),
#  76328: tensor([], device='cuda:0', dtype=torch.int64),
#  76759: tensor([], device='cuda:0', dtype=torch.int64),
#  69074: tensor([], device='cuda:0', dtype=torch.int64),
#  73740: tensor([], device='cuda:0', dtype=torch.int64),
#  52741: tensor([], device='cuda:0', dtype=torch.int64),
#  ...}
